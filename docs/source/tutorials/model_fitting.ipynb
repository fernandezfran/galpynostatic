# %% [markdown]
# # Model fitting

# %% [markdown]
# We use experimental data from the paper by [Lei et al.](https://doi.org/10.1016/j.jallcom.2014.09.169) for LFP system to fit our heuristic model.
#
# First, we import the libraries that we will be using throughout this example:

# %%
import galpynostatic
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data visualization

# %% [markdown]
# We define a [numpy](https://numpy.org/) array with the C-rates that were used to perform the measurements in the experiment.

# %%
C_rates = np.array([0.2, 0.5, 1, 2, 5, 10])

# %% [markdown]
# For each one of these C-rates we have a galvanostatic profile as a csv file, we read them with [pandas](https://pandas.pydata.org/) and store them in a list for further preprocessing.

# %%
gprofiles = [pd.read_csv(f"../_static/{c_rate}C.csv") for c_rate in C_rates]
gprofiles[0].keys()
# Out:
# Index(['capacity', 'voltage'], dtype='object')

# %% [markdown]
# we have a pd.DataFrame for each curve with a capacity and a voltage column. We also define from their work the equilibrium potential and our cut-off potential.

# %%
eq_pot, vcut = 3.45, 0.15

# %% [markdown]
# We plot the curves to visualize them in the region of interest:

# %%
fig, ax = plt.subplots()

for c_rate, df in zip(C_rates, gprofiles):
    ax.scatter(df.capacity, df.voltage, label=f"{c_rate}")
    
ax.set_xlim((0, 180))
ax.set_ylim((eq_pot - vcut, eq_pot + vcut))
ax.set_xlabel(r"Specific Capacity (mAh g$^{-1}$)")
ax.set_ylabel(r"Potential (V vs. Li$^+$/Li)")
ax.legend(title="C rate")
plt.show()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# In the physics-based heuristic model we present here, we are not interested in the complete behavior of the profile, but focus our analysis on the points where each curve intersects at a cut-off potential below the equilibrium potential. To obtain these values we can use the `galpynostatic.preprocessing` module.

# %%
gdc = galpynostatic.preprocessing.GetDischargeCapacities(eq_pot, vcut=vcut)
dc = gdc.fit_transform(gprofiles)
dc
# Out:
# array([160.27911  , 141.21538  , 128.30042  ,  55.622726 ,   3.5315654,
#          1.6230893], dtype=float32)

# %% [markdown]
# We must normalize these currents by a maximum value that we define (here we use the maximum value of the capacity for the lowest C-rate reported in the paper as 168.9 mAh g$^{-1}$) to obtain the maximum SOC value between 0 and 1, which are going to be the target values of our model.

# %%
soc = dc / 168.9

# %% [markdown]
# ## Fitting

# %% [markdown]
# First, we show the data in the form to be used by the model

# %%
fig, ax = plt.subplots()

plt.plot(C_rates, soc, marker="s", ls="--")

plt.xlabel("C-rate")
plt.ylabel("SOC")
plt.xscale("log")
plt.show()

# %% [markdown]
# and reshape the C-rate values as in the usual way used by [scikit-learn](https://scikit-learn.org/stable/) convention.

# %%
C_rates = C_rates.reshape(-1, 1)

# %% [markdown]
# In the paper it is mentioned that the particle sizes are distributed between 200-500 nm, we take the mid point and give it in cm which is the required unit.

# %%
d = 3.5e-5

# %% [markdown]
# We load the surface data for spherical geometry with a 150 mV cut-off potential and define the z-value which is a number that depends on the geometry, here it is 3.

# %%
dataset = galpynostatic.datasets.load_spherical()
z = 3

# %% [markdown]
# We now have all the information we need to fit the model.

# %%
greg = galpynostatic.model.GalvanostaticRegressor(dataset, d, z)
greg.fit(C_rates, soc)
# Out:
# GalvanostaticRegressor(d=3.5e-05,
#                        dataset=        l  chi      xmax
# 0   -4.00  2.0  0.997060
# 1   -4.00  1.9  0.997060
# 2   -4.00  1.8  0.997050
# 3   -4.00  1.7  0.997050
# 4   -4.00  1.6  0.997050
# ..    ...  ...       ...
# 985  1.75 -0.2  0.005740
# 986  1.75 -0.3  0.004180
# 987  1.75 -0.4  0.002560
# 988  1.75 -0.5  0.001110
# 989  1.75 -0.6  0.000185
#
# [990 rows x 3 columns],
#                        z=3)

# %% [markdown]
# Two types of plots are available, one to visualize the region of the map where the experimental data are located after the adjustment

# %%
greg.plot.in_surface(C_rates)
plt.legend()
plt.show()

# %% [markdown]
# and another to visualize the predicted versus experimental values in the same format as used for the fitting.

# %%
greg.plot.versus_data(C_rates, soc)
plt.legend()
plt.show()

# %% [markdown]
# ## Predictions

# %% [markdown]
# We can obtain fundamental parameters of the system by accessing attributes of the `GalvanostaticRegressor` model, such as the diffusion coefficient (in cm$^2$/s)

# %%
greg.dcoeff_
# Out:
# 2.848035868435805e-13

# %% [markdown]
# which in this case is in high agreement with the three values reported in their work of 1.04e-12, 1.74e-13 and 8.22e-13 (EIS measurements).

# %% [markdown]
# In addition, we can obtain the kinetic rate constant (in cm/s)

# %%
greg.k0_
# Out:
# 1e-09

# %% [markdown]
# that is also in high agreement with the experimental one of 1.23e-9, calculated using the [Butler-Volmer equation](https://en.wikipedia.org/wiki/Butler%E2%80%93Volmer_equation) with the reported exchange current density value.

# %% [markdown]
# Finally, there is a gast-charging standard, proposed by the _United States Advanced Battery Consortium_ (USABC), which aims for extremely fast-charging of 80% of the State-of-Charge (SOC) in 15 minutes. This translates to a SOC value of 0.8 and a C-rate of 4C. A prediction on the particle size needed to satisfy this criterion can be quickly made with the `optimal_particle_size` function in `galpynostatic.make_prediction` module (which has the default values of the criterion defined).

# %%
d_new = galpynostatic.make_prediction.optimal_particle_size(greg, cm_to=1)
d_new
# Out:
# 8.36253773855037e-06

# %% [markdown]
# This value is in cm and can be compared with the original one (d)

# %%
d
# Out:
# 3.5e-05

# %% [markdown]
# where it can be seen that our model predicts that the system should be improved by reducing the particle size by about one order of magnitude.
